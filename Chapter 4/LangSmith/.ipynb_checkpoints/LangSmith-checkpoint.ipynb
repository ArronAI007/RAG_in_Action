# %%
import os
from dotenv import load_dotenv

# 加载 .env 文件中的环境变量
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

llm.invoke("what's generative ai?")
# Out:
# AIMessage(content='Generative AI refers to artificial intelligence systems that are designed to generate new content, such as images, texts, or music, based on patterns and data input. These systems use machine learning algorithms to analyze and understand the data, and then create new content that resembles the input data. Generative AI is used in various fields such as art, design, and entertainment, and has the potential to create unique and innovative content.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 13, 'total_tokens': 98, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-2b83ef73-f690-4bdd-80c1-aa2db87a0dcf-0', usage_metadata={'input_tok
# ...

# %% [markdown]
# 登录LangSmith官网查看日志记录情况

# %% [markdown]
# ![image.png](attachment:3f2338ef-fdcf-4717-8c68-42b51a9e222e.png)
